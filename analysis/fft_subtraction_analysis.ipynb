# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import glob
import os
import numpy as np
from scipy import fftpack
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import FastICA
from scipy.signal import butter, filtfilt
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as scipy_signal
import pywt
from scipy.stats import wilcoxon
import matplotlib.cm as cm
import numpy as np
from sklearn.utils import resample
import h5py
import pickle
import scipy.io

# %% [markdown]
# ### Figure settings

# %%
plt.rcParams['font.family'] = 'Ubuntu Sans'

# %%
import matplotlib.font_manager
print([f.name for f in matplotlib.font_manager.fontManager.ttflist])
# Out:
# ['cmsy10', 'DejaVu Sans Mono', 'DejaVu Sans', 'STIXSizeThreeSym', 'cmmi10', 'STIXSizeOneSym', 'STIXGeneral', 'DejaVu Sans Display', 'DejaVu Serif', 'DejaVu Sans Mono', 'STIXSizeOneSym', 'STIXGeneral', 'DejaVu Serif', 'DejaVu Sans Mono', 'cmex10', 'DejaVu Sans', 'DejaVu Serif', 'STIXSizeThreeSym', 'STIXGeneral', 'STIXSizeTwoSym', 'DejaVu Serif', 'DejaVu Sans Mono', 'STIXGeneral', 'STIXNonUnicode', 'STIXSizeFourSym', 'cmb10', 'DejaVu Sans', 'DejaVu Serif Display', 'STIXSizeFiveSym', 'STIXNonUnicode', 'cmss10', 'cmr10', 'STIXSizeFourSym', 'STIXNonUnicode', 'cmtt10', 'DejaVu Sans', 'STIXNonUnicode', 'STIXSizeTwoSym', 'Inconsolata', 'Source Code Pro', 'Ubuntu', 'Source Code Pro', 'Ubuntu Sans', 'Ubuntu', 'Ubuntu Mono', 'Ubuntu', 'Source Code Pro', 'Ubuntu Mono', 'Ubuntu', 'Ubuntu', 'Ubuntu', 'Ubuntu Mono', 'Ubuntu', 'Ubuntu Mono', 'Source Code Pro', 'DejaVu Serif', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'Ubuntu Sans Mono', 'Source Code Pro', 'Ubuntu', 'Source Code Pro', 'Source Code Pro', 'Ubuntu', 'Ubuntu', 'Source Code Pro', 'Ubuntu', 'Ubuntu', 'Source Code Pro', 'DejaVu Sans', 'Ubuntu', 'Ubuntu', 'DejaVu Sans', 'Ubuntu', 'Ubuntu Sans Mono', 'DejaVu Sans Mono', 'Ubuntu Mono', 'Ubuntu', 'Ubuntu Sans', 'Source Code Pro', 'Ubuntu Mono', 'Ubuntu', 'Ubuntu Mono', 'Source Code Pro', 'Ubuntu', 'Ubuntu Condensed', 'Ubuntu Mono', 'DejaVu Serif', 'Ubuntu', 'Ubuntu Mono', 'Ubuntu Mono', 'Source Code Pro', 'Ubuntu', 'Ubuntu', 'DejaVu Sans Mono', 'Source Code Pro', 'Inconsolata', 'Source Code Pro', 'DejaVu Sans']

# %% [markdown]
# ### Definitions

# %%
def read_data(subjid, pattern):
    files = glob.glob(pattern)
    print(files)
    
    import os

    for file in files:
        print(f"\nChecking file: {file}")
        print(f"  Exists: {os.path.exists(file)}")
        print(f"  Is file: {os.path.isfile(file)}")
        print(f"  File size: {os.path.getsize(file) if os.path.exists(file) else 'N/A'} bytes")
    
    data = {} # Accumulator
    freq_amp_table = []
    
    # Everything below can go to separate function
    for file in files:
        current_filename = file
        try:
            f = h5py.File(current_filename, 'r')
        except OSError:
            print(f"Skipping {current_filename} - cannot read file")
            continue
                
        ex_data = f['ex']

        freq_by_amp = ex_data[:].shape
        num_tested_freqs = freq_by_amp[1]
        num_tested_amps = freq_by_amp[0]
            
        channel_keys = ['ch1','ch2','ch3','ch4']
        period_keys = ['prestim_sig','stimresp_sig','poststimresp_sig']

        for tested_freqs in range(num_tested_freqs):
            for tested_amps in range(num_tested_amps):
                
                obj = f[ex_data[tested_amps,tested_freqs]]
                if isinstance(obj, h5py.Group): # i.e., checks if the cell actually had a ex template populated or is just [] (no freq, amp, etc. assigned)
                    # Empty arrays in matlab are still seen as datasets, so the way to check if there is anything inside a combo
                    # Is by checking if there are references for the signals at all
                    obj = f[ex_data[tested_amps,tested_freqs]]['electrodes']['ch1']['signals']['stimresp_sig'][:]
                    if obj.dtype == object: # i.e., checks if the cell, which has a populated template, actually has any data in it
                        # It's a group, access the 'decision' dataset inside
                        decision_ref = f[ex_data[tested_amps,tested_freqs]]['decision']
                        decision = f[ex_data[tested_amps,tested_freqs]]['decision'][:]
                        
                        if len(decision.shape) > 0:
                            freq_ref = f[ex_data[tested_amps,tested_freqs]]['frequency']
                            amp_ref = f[ex_data[tested_amps,tested_freqs]]['amplitude']
                            freq = freq_ref[0][0]
                            amp = amp_ref[0][0]
                            
                            freq_amp_table.append([freq,amp])
                            
                            period_len_ref = f[ex_data[tested_amps,tested_freqs]]['electrodes']['ch1']['signals']['stimresp_sig']
                            actual_data = f[period_len_ref[0, 0]][:] #use the first reference address to get actual data
                            period_len = actual_data.shape[0]
                            
                            if (freq, amp) not in data:
                                data[freq, amp] = []

                            data[freq, amp].append({'filename': current_filename, 'decision': decision, 'period_len': period_len})
                            
                            for channel in channel_keys:
                                sig_ref = f[ex_data[tested_amps,tested_freqs]]['electrodes'][channel]['signals']['stimresp_sig']
                                num_batches = sig_ref.shape[0]
                                all_batches = []
                                
                                print(f" sig_ref shape {sig_ref.shape}")
                                for batch in range(num_batches):
                                    sig = []
                                    for period in period_keys:
                                        sig_ref = f[ex_data[tested_amps,tested_freqs]]['electrodes'][channel]['signals'][period]
                                        sig.append(f[sig_ref[batch][0]][:])
                                    current_batch_all_periods = np.concatenate(sig)
                                    all_batches.append(current_batch_all_periods)
                                    
                                    print(f"Channel: {channel}")
                                    print(f"  current_batch_all_periods shape: {current_batch_all_periods.shape}")
                                    print(f"  len(all_batches): {len(all_batches)}")
                                
                                print(f"  all_batches array shape: {np.array(all_batches).shape}")
                                # Squeeze out the batches in dataset (1 batch = a set of trials)
                                sig_len = current_batch_all_periods.shape[0]
                                data[freq, amp][-1][channel] = np.array(all_batches).T.transpose(0, 2, 1).reshape(-1, sig_len)
                    else:
                        print(f"{current_filename},{tested_freqs},{tested_amps}, does not have data inside")
                else:
                    print(f"{current_filename},{tested_freqs},{tested_amps}, does not have references")
        
    return data, freq_amp_table
# Check 11/20/2025

# %%
def define_basic_vars():
    fs = 22050
    latency = 2118
    channel_keys = ['ch1','ch2','ch3','ch4']
    period_keys = ['prestim','stimresp']
    metric_keys = ['mean','std']
    submetric_keys = ['doub_freq_mag','SNR']
    return fs, latency, channel_keys, period_keys, metric_keys, submetric_keys
# check 11/20/2025

# %%
def pickle_data(subjid):
    np.savez(f'{subjid}_data.npz',
    data=data,
    freq_amp_table=freq_amp_table,
    latency=latency,
    channel_keys=channel_keys)
# If need to keep this dataset in python friendly form

# %%
def load_data(subjid):
    # example 'hydrolagusColliei_8'
    loaded = np.load(f'/mnt/c/Users/seaudlab/Documents/hydroC/{subjid}_data.npz', allow_pickle=True) # Aoi
    #loaded = np.load(f'{subjid}_data.npz', allow_pickle=True)
    data = loaded['data']
    freq_amp_table = loaded['freq_amp_table']
    
    return data, freq_amp_table

# %%
def remove_artefacts(data):
    # Loop through each (freq, amp) key
    for coord, dataset_list in data.items():
        # Loop through each dataset in the list
        for dataset_idx, dictionary in enumerate(dataset_list):
            print(f"Processing coord {coord}, dataset {dataset_idx}")
            
            # Artifact removal for each channel
            for channel in ['ch1', 'ch2', 'ch3', 'ch4']:
                print(dictionary[channel].shape)
                rms_per_row = np.sqrt(np.mean(dictionary[channel]**2, axis=1))
                print(f"{channel}: rms = {rms_per_row.shape}")
                rms_mean = np.mean(rms_per_row) # calculate mean rms across all trials
                rms_std = np.std(rms_per_row) # calculate std rms across all trials
                
                # See which rows has an rms that is too high (i.e., artifact) and remove them
                threshold = rms_mean + (rms_std*3)
                keep_rows = rms_per_row <= threshold
                dictionary[channel] = dictionary[channel][keep_rows]
                dictionary[f'{channel}_total_trials'] = dictionary[channel].shape[0]
            
            # Determine the minimum number of trials across all channels
            min_trials = min([dictionary[f'{channel}_total_trials'] for channel in ['ch1', 'ch2', 'ch3', 'ch4']])
            
            # Randomly select the same number of trials for each channel
            for channel in ['ch1', 'ch2', 'ch3', 'ch4']:
                np.random.seed(42)
                
                # Get indices for the channel
                channel_indices = np.arange(dictionary[channel].shape[0])
                
                # Randomly select indices
                selected_indices = np.random.choice(channel_indices, size=min_trials, replace=False)
                
                # Update the channel data with selected trials
                dictionary[channel] = dictionary[channel][selected_indices]
                
                # Update the total trials count
                dictionary[f'{channel}_total_trials'] = min_trials
    
    return data

# Check 11/20/2025

# %%
def select_stimulus(data, myfreq, myamp, dataset_index):
    specific_key = (np.float64(myfreq), np.float64(myamp))
    all_datasets = data[specific_key]  # This is a list now
    
    print(f"Found {len(all_datasets)} dataset(s) for freq={myfreq}, amp={myamp}")
    print(f"Selecting dataset {dataset_index} from file: {all_datasets[dataset_index]['filename']}")
    
    return all_datasets[dataset_index]
# checked 11/20/2025

# %%
def bandpass(data, low, high, fs, order=4):
    ny = 0.5 * fs
    b, a = butter(order, [low/ny, high/ny], btype='band')
    return filtfilt(b, a, data, axis=1)

# check 11/20/2025
# For digital (as opposed to non-discretised analog) filters, if fs is not specified, 
# Wn units are normalized from 0 to 1,where 1 is the Nyquist frequency (Wn is thus in half-cycles / sample).

# %% [markdown]
# #### Analysis definitions

# %%
def add_weights(data, channel_keys, weights):
    weighted_data = {}
    for idx, channel in enumerate(channel_keys):
        current_data = data[channel]
        current_weight = weights[idx]
        weighted_data[channel] = current_data * current_weight
    return weighted_data

# %%
def separate_periods(data, current_cond, period_keys, channel_keys, latency):
    separated_data = {
        'prestim': {},
        'stimresp': {}
    }
    
    period_len = current_cond['period_len']
    
    for period in period_keys:
        for channel in channel_keys:            
            if period == 'prestim':
                separated_data[period][channel] = data[channel][:,latency:latency+period_len]     
            elif period == 'stimresp':
                separated_data[period][channel] = data[channel][:,latency+period_len:latency+period_len*2]
                
    return separated_data
# check 11/20/25 latency is what i need to shift the slicing by see obsidian note "Latency issue 8-26-25"
# confimed that the two period slices do not overlap with one another

# %%
def compute_fft(data, channel_keys, period_keys,smallest_dim, fs):
    # No channels or periods
    if len(period_keys) == 0 and len(channel_keys) == 0:
        fft_magnitudes = {}
        fft_freq_vecs = {}
        
        trial_magnitudes = []
        freq_vecs = []
        
        if smallest_dim == 1:
            num_cols = data.shape[smallest_dim]
            for trial in range(num_cols):
                cur_trial = data[:,trial]
                n_samples = len(cur_trial)
                # Calculate frequencies for positive frequencies only
                freqs = np.fft.rfftfreq(fs, d=1/fs) # fs= window length, d = sampling period
                
                # Calculate magnitude spectrum
                fft_vals = np.fft.rfft(cur_trial,n=fs) # cur_trial= data to do, fs = zero pad up to the fs
                magnitude = np.abs(fft_vals)/n_samples # divide by the number of samples to recover magntiude values                
                trial_magnitudes.append(magnitude)
                freq_vecs.append(freqs)
                    
                fft_magnitudes = np.vstack(trial_magnitudes)
                fft_freq_vecs = np.vstack(freq_vecs)
    
    # Only have channels        
    elif len(period_keys) == 0 and len(channel_keys) > 0:
        # Initialize dictionaries with nested structure
        fft_magnitudes = {}
        fft_freq_vecs = {}
        
        for channel in channel_keys:
            trial_magnitudes = []
            freq_vecs = []
            num_trial = min(data[channel].shape)
            for trial in range(num_trial):
                cur_trial = data[channel][trial]
                n_samples = len(cur_trial)
                # Calculate frequencies for positive frequencies only
                freqs = np.fft.rfftfreq(fs, d=1/fs)
                
                # Calculate magnitude spectrum
                fft_vals = np.fft.rfft(cur_trial,n=fs)
                magnitude = np.abs(fft_vals)/n_samples
                
                trial_magnitudes.append(magnitude)
                freq_vecs.append(freqs)
                
            fft_magnitudes[channel] = np.vstack(trial_magnitudes)
            fft_freq_vecs[channel] = np.vstack(freq_vecs)
    
    # Have both period and channel delination
    elif len(period_keys) > 0 and len(channel_keys) > 0: 
        # Initialize dictionaries with nested structure
        fft_magnitudes = {period: {} for period in period_keys}
        fft_freq_vecs = {period: {} for period in period_keys}
        
        for period in period_keys:
            for channel in channel_keys:
                trial_magnitudes = []
                freq_vecs = []
                num_trial = data[period][channel].shape[0]
                
                for trial in range(num_trial):
                    cur_trial = data[period][channel][trial]
                    n_samples = len(cur_trial)
                    # Calculate frequencies for positive frequencies only
                    freqs = np.fft.rfftfreq(fs, d=1/fs)
                    
                    # Calculate magnitude spectrum
                    fft_vals = np.fft.rfft(cur_trial,n=fs)
                    magnitude = np.abs(fft_vals)/n_samples
                    
                    trial_magnitudes.append(magnitude)
                    freq_vecs.append(freqs)
                    
                fft_magnitudes[period][channel] = np.vstack(trial_magnitudes)
                fft_freq_vecs[period][channel] = np.vstack(freq_vecs)
    
    # Return both dictionaries
    return fft_magnitudes, fft_freq_vecs
# Check 11/20/2025

# %%
def find_large_stds(data, freq_vecs, period_keys, channel_keys, metric_keys, myfreq):
    my_rat_data = {}
    my_SNR_data = {}
    target_freq = myfreq*2
    for channel in channel_keys.copy():
        my_rat_data[channel] = []
        cur_avg = data['average']['stimresp'][channel]
        print(len(cur_avg))
        cur_std = data['std']['stimresp'][channel]
        cur_freq_vec = freq_vecs['stimresp'][channel][0]
        
        # Double frequency mask (3 Hz tolerance)
        doub_mask = np.abs(cur_freq_vec - target_freq) <= 3
        my_mean = cur_avg[doub_mask]
        my_std = cur_std[doub_mask]
        my_rat = my_std/my_mean
        my_rat_data[channel].append(my_rat)
        
        print(f"{channel} : {my_rat}")
    
        if my_rat > 6:
            print(f"Warning {channel} has super high std value")
            
    filt_channel_keys = channel_keys

    return my_rat_data, filt_channel_keys

# %% [markdown]
# ### ICA related defs

# %%
def reshape_the_data(data, channel_keys, period_keys, bootstrapped=False):
    # Reshape to (trials * samples) x channels
    reshaped_list = []
    for channel in channel_keys:
        cur_set = data[channel]
        reshaped_list.append(cur_set.reshape(-1, 1))
    
    reshaped_data = np.hstack(reshaped_list)
    return reshaped_data

# check 11/20/2025
# X = array-like of shape (n_samples, n_features)

# %%
def perform_ICA(data, channel_keys):
    start = time.perf_counter()
    
    # Standardize the data
    # Removes the mean and sets variance across ICs to 1, necessary for ICA to work
    # Standardization of a dataset is a common requirement for many machine learning estimators: 
    # they might behave badly if the individual features do not
    # more or less look like standard normally distributed data (e.g. Gaussian with 0 mean and unit variance).
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data)

    # Improved FastICA configuration
    # Use default variables more or less except max_iter set to 500 instead of 200
    ica = FastICA(
        n_components=len(channel_keys), 
        random_state=42,  # More robust random seed
        max_iter=500,     # Increased iterations
        tol=1e-4,         # Tightened tolerance???
        whiten='unit-variance'  # Corrected whiten parameter
    )
    
    S = ica.fit_transform(data_scaled)
    A = ica.mixing_

    end = time.perf_counter()
    elasped = end - start
    
    # Convergence check
    print(f"Elapsed time: {elasped:.2f} seconds")
    print(f"ICA Convergence: {ica.n_iter_}")
    
    # Store results in dictionary
    ica_results = {
        'S': S,
        'A': A,
        'n_iter': ica.n_iter_,
        'elapsed_time': elasped
    }
    
    return ica_results

# check 11/20/2025

# %%
def calculate_diff_CI(data, submetric):
    prestim = data['prestim'][submetric]
    stimresp = data['stimresp'][submetric]
    diff = stimresp - prestim

    # 2. Compute 95% confidence interval for the difference (non-parametric confidence interaval)
    lower = float(np.percentile(diff, 2.5))
    upper = float(np.percentile(diff, 97.5))

    print("95% CI:", (lower, upper))

    # 3. Decision rule: if CI excludes 0 → significant
    if lower > 0 or upper < 0:
        print("Groups differ significantly (CI excludes 0).")
    else:
        print("No significant difference (CI includes 0).")
    
    return [lower, upper]
# Check 11/20/25
# source for why you cannot do t-tests/etc. on bootstrapped distributions
# https://www.stat.umn.edu/geyer/5601/examp/tests.html?utm_source=chatgpt.com
# If 0 is included in 95% CI then diff of 0 is a plausible value for the true difference

# %%
def select_doub_freq_bin(data, frequencies, period_keys, myfreq, window_size=100):
    if len(period_keys) == 0:
        doub_freq_dict = {}
        
        target_freq = 2*myfreq
        part_window = window_size/2
        artifact_freqs = [myfreq, target_freq, 60, 120, 180, 240, 300, 360, 420, 480, 540, 600, 660, 720, 780, 840, 900]
        freq_vec = frequencies[0]
            
        # Double frequency mask (3 Hz tolerance)
        doub_mask = np.abs(freq_vec - target_freq) <= 3
        print(doub_mask.shape)
        print(freq_vec[doub_mask])
        window_mask = (freq_vec >= target_freq-part_window) & (freq_vec <= target_freq+part_window)
        print(freq_vec[window_mask])
        
        for freq in artifact_freqs:
            art_mask = np.abs(freq_vec - freq) <= 3
            window_mask[art_mask] = False
        print(freq_vec[window_mask])
            
        num_it = data.shape[0]

        doub_freq_tmp = []
        snr_tmp = []
        
        for cur_it in range(num_it):
            cur_data = data[cur_it]
            doub_mag = cur_data[doub_mask]
            remain_mag = cur_data[window_mask]
            
            doub_mag = np.mean(doub_mag)
            remain_mag = np.mean(remain_mag)
            print(doub_mag)
            print(remain_mag)
            
            doub_freq_tmp.append(doub_mag)
            snr_tmp.append((doub_mag) - (remain_mag)) # when already in dB
            print('dB subtraction performed!')
            # snr_tmp.append(20 * np.log10((doub_mag) / (remain_mag)))
            
        # Move this inside the period loop
        doub_freq_dict = {
            'doub_freq_mag': np.hstack(doub_freq_tmp),
            'SNR': np.hstack(snr_tmp)
        }
        
    elif len(period_keys) > 0:
        doub_freq_dict = {
            'prestim': {},
            'stimresp': {}
        }
            
        target_freq = 2*myfreq
        part_window = window_size/2
        artifact_freqs = [myfreq, target_freq, 60, 120, 180, 240, 300, 360, 420, 480, 540, 600, 660, 720, 780, 840, 900]
        freq_vec = frequencies['prestim']['ch1']
        # Double frequency mask (3 Hz tolerance)
        doub_mask = np.abs(freq_vec - target_freq) <= 3
        window_mask = (freq_vec >= target_freq-part_window) & (freq_vec <= target_freq+part_window)
        print(window_mask.shape)
        
        for freq in artifact_freqs:
            art_mask = np.abs(freq_vec - freq) <= 3
            window_mask[art_mask] = False
            
        num_it = len(data['prestim'])
        doub_mask = doub_mask[0] # I am doing this since freq_vec is a matrix? check this...
        print(freq_vec[0][doub_mask])
        window_mask = window_mask[0]
        print(window_mask.shape)
        print(freq_vec[0][window_mask])
        
        print(num_it)
        
        for period in period_keys:
            doub_freq_tmp = []
            snr_tmp = []
            for cur_it in range(num_it):
                cur_data = data[period][cur_it]
                doub_mag = cur_data[doub_mask]
                remain_mag = cur_data[window_mask]
                
                doub_mag = np.mean(doub_mag)
                remain_mag = np.mean(remain_mag)
                
                doub_freq_tmp.append(doub_mag)
                snr_tmp.append(20 * np.log10((doub_mag) / (remain_mag)))
            
            # Move this inside the period loop
            doub_freq_dict[period] = {
                'doub_freq_mag': np.hstack(doub_freq_tmp),
                'SNR': np.hstack(snr_tmp)
            }
            
    return doub_freq_dict
# check 11/20/25

# %%
def create_ICA_weights(data):
    # doub_freq_ICA = data
    weights = []
    snr_db = data['SNR']
    linear_snr = 10**(snr_db/10) # take the inverse log to calculate linear_snr
    weights = linear_snr / linear_snr.sum() # normalize by the sum of the snrs
    
    return weights
# check 11/20/25

# %%
def weight_and_reconstruct_ica(ica_results, current_cond, channel_keys, components_to_keep, component_weights=None):
    recon_restruct_data = {}
    
    # Extract ICA results
    S = ica_results['S']
    A = ica_results['A']
    
    # Create a weighted reconstruction
    if component_weights is None:
        # If no weights provided, use default (keeping all selected components equally)
        component_weights = np.ones(len(components_to_keep))
    
    # Ensure weights match the number of components to keep
    assert len(component_weights) == len(components_to_keep), "Number of weights must match number of components"
    
    # Filter independent components
    S_filtered = S[:, components_to_keep]
    A_filtered = A[:, components_to_keep]
    
    # Apply weights to the independent components
    S_weighted = S_filtered * component_weights
    
    # Reconstruct the data with weighted components
    # np.dot = Multiply rows of left matrix with columns of right matrix and sums the products
    reconstructed_data = np.dot(S_weighted, A_filtered.T) # Matrix multiplication of the two matrices to get signals back
    
    n_trials = current_cond['ch1'].shape[0]
    n_samples_per_trial = current_cond['ch1'].shape[1]
    
    for idx, channel in enumerate(channel_keys):
        recon_restruct_data[channel] = reconstructed_data[:, idx].reshape(n_trials, n_samples_per_trial)  
    
    return recon_restruct_data
# check 11/20/25

# %%
def compare_denoised_waveform(filt_data, recon_restruct_data, channel_keys, myfreq, myamp, subjid, fs, dataset_index, fft_ylim=None):
    data_type = ['original','denoised']
    # Calculate grand mean
    compare_denoising_mean = {
        'original': {channel: np.mean(filt_data[channel], axis=0) for channel in channel_keys},
        'denoised': {channel: np.mean(recon_restruct_data[channel], axis=0) for channel in channel_keys}
    }

    compare_denoising_std = {
        'original': {channel: np.std(filt_data[channel], axis=0) for channel in channel_keys},
        'denoised': {channel: np.std(recon_restruct_data[channel], axis=0) for channel in channel_keys}
    }
    
    # Calculate ffts
    fft_magnitudes_mean = {
        'original': {},
        'denoised': {}
    }
    
    fft_magnitudes_std = {
        'original': {},
        'denoised': {}
    }
    
    fft_freq_vecs = {
        'original': {},
        'denoised': {}
    }
    
    for dtype in data_type:
        for channel in channel_keys:
            cur_mag_mean = compare_denoising_mean[dtype][channel]
            cur_mag_std = compare_denoising_std[dtype][channel]
            n_samples = len(cur_mag_mean)
            
            # Frequency vector
            freqs = np.fft.rfftfreq(fs, d=1/fs)
            fft_freq_vecs[dtype][channel] = freqs
            
            # Mean
            fft_vals = np.fft.rfft(cur_mag_mean, n=fs)
            magnitude = np.abs(fft_vals)/n_samples
            fft_magnitudes_mean[dtype][channel] = magnitude
            
            # STD
            fft_vals = np.fft.rfft(cur_mag_std,n=fs)
            magnitude = np.abs(fft_vals)/n_samples
            fft_magnitudes_std[dtype][channel] = magnitude
        
    # Waveform plot
    n_channels = len(channel_keys)
    fig, axes = plt.subplots(n_channels, 2, figsize=(12, 3*n_channels), sharex=True, sharey=True)

    for i, channel in enumerate(channel_keys):
        # Left column: Original
        ax_orig = axes[i, 0] if n_channels > 1 else axes[0]
        mean_orig = compare_denoising_mean['original'][channel]
        std_orig = compare_denoising_std['original'][channel]
        
        ax_orig.plot(mean_orig, label='Mean', color='#5778a4')
        ax_orig.fill_between(range(len(mean_orig)), 
                            mean_orig - std_orig, 
                            mean_orig + std_orig, 
                            alpha=0.3, color='#5778a4')
        ax_orig.set_title(f'{channel} - Original')
        ax_orig.set_ylabel('Value')
        if i == n_channels - 1:
            ax_orig.set_xlabel('Time/Sample')
        
        # Right column: Denoised
        ax_denoise = axes[i, 1] if n_channels > 1 else axes[1]
        mean_denoise = compare_denoising_mean['denoised'][channel]
        std_denoise = compare_denoising_std['denoised'][channel]
        
        ax_denoise.plot(mean_denoise, label='Mean', color='#e49444')
        ax_denoise.fill_between(range(len(mean_denoise)), 
                                mean_denoise - std_denoise, 
                                mean_denoise + std_denoise, 
                                alpha=0.3, color='#e49444')
        ax_denoise.set_title(f'{channel} - Denoised')
        ax_denoise.set_ylabel('Value')
        if i == n_channels - 1:
            ax_denoise.set_xlabel('Time/Sample')

    plt.tight_layout()
    plt.savefig(f"plots/{subjid}/{subjid}_{myfreq}Hz_{myamp}dB_compare_ICA_denoised_waveform_{dataset_index}.png", 
                format='png', 
                bbox_inches='tight', 
                dpi=600)
    plt.show()
    
    # FFT plot
    n_data_types = len(data_type)
    fig, axes = plt.subplots(n_channels, n_data_types, figsize=(6*n_data_types, 4*n_channels),sharex=True,sharey=True)

    # Handle case where axes might not be 2D array
    if n_channels == 1:
        axes = axes.reshape(1, -1)
    if n_data_types == 1:
        axes = axes.reshape(-1, 1)

    # Plot each combination
    for i, channel in enumerate(channel_keys):
        for j, dtype in enumerate(data_type):
            ax = axes[i, j]
            
            # Get data for this channel and data type
            freqs = fft_freq_vecs[dtype][channel]
            mean_mag = fft_magnitudes_mean[dtype][channel]
            std_mag = fft_magnitudes_std[dtype][channel]
            
            # Plot mean line
            if dtype == 'original':
                ax.plot(freqs, mean_mag, linewidth=2,color='#5778a4', label='Mean')
                
            if dtype == 'denoised':
                ax.plot(freqs, mean_mag, linewidth=2,color='#e49444', label='Mean')
            
            # Plot shaded std area
            if dtype == 'original':
                ax.fill_between(freqs, 
                                mean_mag - std_mag, 
                                mean_mag + std_mag, 
                                alpha=0.3,
                                color='#5778a4',
                                label='±1 SD')
            
            if dtype == 'denoised':
                ax.fill_between(freqs, 
                                mean_mag - std_mag, 
                                mean_mag + std_mag, 
                                alpha=0.3,
                                color='#e49444',
                                label='±1 SD')
            
            # Labels
            ax.set_xlabel('Frequency (Hz)')
            ax.set_ylabel('Magnitude')
            ax.set_title(f'{channel} - {dtype}')
            ax.legend()
            ax.grid(True, alpha=0.3)
            ax.set_ylim(fft_ylim)
            ax.set_xlim([(myfreq*2-100), (myfreq*2+100)])
            ax.axvline(x=myfreq*2, color='r', linestyle='--', linewidth=.5)
            
    plt.tight_layout()
    # Save figure
    plt.savefig(f"plots/{subjid}/{subjid}_{myfreq}Hz_{myamp}dB_compare_ICA_denoised_fft_{dataset_index}.png", 
                format='png', 
                bbox_inches='tight', 
                dpi=600)
    plt.show()
    
    return compare_denoising_mean, compare_denoising_std, fft_magnitudes_mean, fft_magnitudes_std, fft_freq_vecs
# check 11/20/2025

# %% [markdown]
# ### Bootstrapped related

# %%
def collapse_channels(data, period_keys, channel_keys):
    collapsed_dict = {
        'prestim': None,
        'stimresp': None
    }
    for period in period_keys:
        tmp = []
        for channel in channel_keys:
            tmp.append(data[period][channel])
        collapsed_dict[period] = np.vstack(tmp)
        
    return collapsed_dict
# check 11/20/25

# %%
def calculate_bootstrap(data, period_keys, channel_keys, n_iterations, random_state=42):
    # Ensure consistent random sampling across iterations
    rng = np.random.default_rng(random_state) # create a standalone random number generator object
    # Determine the maximum number of samples across periods
    max_samples = max(len(data[period]) for period in period_keys)
    print(max_samples)

    boot_means = {period: [] for period in period_keys}
    boot_std = {period: [] for period in period_keys}

    for _ in range(n_iterations):
        # Generate a single set of indices to use for all periods (i.e., paired bootstrap)
        sample_indices = rng.choice(max_samples, size=max_samples, replace=True)

        for period in period_keys:
            cur_data = data[period]

            # Resample using the same indices for each period
            resampled_data = cur_data[sample_indices]

            boot_means[period].append(np.mean(resampled_data, axis=0))
            boot_std[period].append(np.std(resampled_data, axis=0))

    
    return boot_means, boot_std
# check 11/20/25

# %% [markdown]
# #### Plotting definitions

# %%
def plot_waveforms(data, channel_keys, title='Check waveforms', num_samples=5, figsize=(8, 4), alpha=0.25):
    if len(channel_keys) == 0:
        num_row = data.shape[1]
        fig, axes = plt.subplots(num_row, 1, figsize=figsize, sharex=True, sharey=True)

        for row_idx in range(num_row):
            ax = axes[row_idx]
            current_data = data[:,row_idx]
            ax.plot(current_data, alpha=alpha)
            
    else:
        fig, axes = plt.subplots(len(channel_keys), 1, figsize=figsize, sharex=True, sharey=True)
        
        if len(channel_keys) == 1:
            axes = [axes]
        
        for row_idx, channel in enumerate(channel_keys):
            ax = axes[row_idx]
            current_data = data[channel]
            
            random_indices = np.random.choice(current_data.shape[0], 
                                            size=min(num_samples, current_data.shape[0]), 
                                            replace=False)
            
            for i in random_indices:
                ax.plot(current_data[i, :], alpha=alpha)
            
            ax.set_ylabel(channel)
    
    fig.suptitle(title)
    fig.tight_layout()
    
    return fig, axes
# Checked 11/20/25

# %%
def plot_fft(magnitudes, frequencies, myfreq, myamp, subjid,  dataset_index, channel_keys, period_keys=None, title='Check waveforms', num_samples=5, figsize=(8, 4), alpha=0.25,xlim=[],ylim=[]):
    if len(channel_keys) == 0:      
        fig, axes = plt.subplots(len(magnitudes), 1, figsize=figsize, sharex=True, sharey=True)
        for row_idx in range(len(magnitudes)):
            ax = axes[row_idx]
            cur_mag = magnitudes[row_idx]
            cur_freq = frequencies[row_idx]
            ax.plot(cur_freq,cur_mag, alpha=alpha)
            
            ax.set_ylabel(str(row_idx))
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.axvline(x=myfreq*2, color='red', linestyle='--', linewidth=.5, label='threshold')
            
    elif len(channel_keys) > 1 and len(period_keys) == 0:
        fig, axes = plt.subplots(len(channel_keys), 1, figsize=figsize, sharex=True, sharey=True)
        for row_idx, channel in enumerate(channel_keys):
            ax = axes[row_idx]
            cur_mag = magnitudes[channel]
            cur_freq = frequencies[channel]
            
            random_indices = np.random.choice(cur_mag.shape[0], 
                                            size=min(num_samples, cur_mag.shape[0]), 
                                            replace=False)
            
            for i in random_indices:
                ax.plot(cur_freq[i, :],cur_mag[i, :], alpha=alpha)
            
            ax.set_ylabel(channel)
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.axvline(x=myfreq*2, color='red', linestyle='--', linewidth=.5, label='threshold')
            
    elif len(channel_keys) > 0 and len(period_keys) > 0:
        fig, axes = plt.subplots(len(channel_keys), len(period_keys), figsize=figsize, sharex=True, sharey=True)
        
        for col_idx, period in enumerate(period_keys):
            for row_idx, channel in enumerate(channel_keys):
                ax = axes[row_idx,col_idx]
                cur_mag = magnitudes[period][channel]
                cur_freq = frequencies[period][channel]
                
                random_indices = np.random.choice(cur_mag.shape[0], 
                                                size=min(num_samples, cur_mag.shape[0]), 
                                                replace=False)
                
                for i in random_indices:
                    ax.plot(cur_freq[i, :],cur_mag[i, :], alpha=alpha)
                
                ax.set_ylabel(channel)
                ax.set_xlim(xlim)
                ax.set_ylim(ylim)
                ax.axvline(x=myfreq*2, color='red', linestyle='--', linewidth=.5, label='threshold')
    
    
    fig.suptitle(f"{subjid} {myfreq} Hz {myamp} dB: {title}")
    fig.tight_layout()
    plt.savefig(f"plots/{subjid}/{subjid}_{myfreq}Hz_{myamp}dB_{title}_{dataset_index}.png", 
        format='png', 
        bbox_inches='tight', 
        dpi=600)
    return fig, axes
# check 11/20/2025

# %%
def plot_doub_freq_hist(doub_freq_dict, subjid, submetric, myfreq, myamp, bin_num, dataset_index):
    # Create the figure 
    fig, ax = plt.subplots(figsize=(15, 10))
    
    # Plot histograms for both periods
    ax.hist(doub_freq_dict['prestim'][submetric], 
            bins=bin_num, 
            alpha=0.6,
            color = '#5778a4')
    ax.hist(doub_freq_dict['stimresp'][submetric], 
            bins=bin_num, 
            alpha=0.6,
            color = '#e49444')
    
    ax.set_title(f"{subjid} {myfreq}Hz {myamp}dB", fontsize=18)
    ax.set_xlabel('AEP Response Relative Magnitude', fontsize=16)
    ax.set_ylabel('Frequency', fontsize=16)
    ax.set_yscale('log')
    ax.tick_params(axis='both', which='major', labelsize=14)
    # ax.legend(fontsize=14)
    
    # Adjust layout
    plt.tight_layout()
    
    # Save figure
    plt.savefig(f"plots/{subjid}/{subjid}_{myfreq}Hz_{myamp}dB_2x_resp_hist_magnitude_{dataset_index}.png", 
                format='png', 
                bbox_inches='tight', 
                dpi=600)
    
    # Show the plot and keep it open
    plt.show()
    # Check 11/20/25

# %%
def plot_bootstrap_fft_comparison(mean_fft_prestim, std_fft_prestim, 
                        mean_fft_stimresp, std_fft_stimresp, 
                        freq_vec, myfreq, myamp, subjid, dataset_index, xlim=None, ylim=None,
                        save_fig=False, save_path=None):
    
    # Create figure with shared axes
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), 
                                    sharex=True, sharey=True)
    
    # Plot prestim FFT
    ax1.plot(freq_vec, mean_fft_prestim, '-',color='#5778a4', label='Mean FFT')
    ax1.fill_between(freq_vec, 
                      mean_fft_prestim - std_fft_prestim,
                      mean_fft_prestim + std_fft_prestim,
                      alpha=0.3, color='#5778a4', label='±1 STD')
    
    # Add vertical line at 2nd harmonic
    ax1.axvline(myfreq*2, color='red', linestyle='--', 
                linewidth = 0.5, alpha=0.7)
    
    ax1.set_xlabel('Frequency (Hz)')
    ax1.set_ylabel('Magnitude')
    ax1.set_title('Stim OFF')
    ax1.grid(True, alpha=0.3)
    ax1.legend()
    
    # Plot stimresp FFT
    ax2.plot(freq_vec, mean_fft_stimresp, '-', color='#e49444',label='Mean FFT')
    ax2.fill_between(freq_vec,
                      mean_fft_stimresp - std_fft_stimresp,
                      mean_fft_stimresp + std_fft_stimresp,
                      alpha=0.3, color='#e49444', label='±1 STD')
    
    # Add vertical line at 2nd harmonic
    ax2.axvline(myfreq*2, color='red', linestyle='--', 
                linewidth = 0.5, alpha=0.7)
    
    ax2.set_xlabel('Frequency (Hz)')
    ax2.set_title('Stim ON')
    ax2.grid(True, alpha=0.3)
    ax2.legend()
    
    # Set x limits if provided
    if xlim is not None:
        ax1.set_xlim(xlim)
        
    if ylim is not None:
        ax1.set_ylim(ylim)
    
    plt.tight_layout()
    
    # Save figure if requested
    if save_fig:
        filename = f"plots/{subjid}/{subjid}_{myfreq}Hz_{myamp}dB_grand_avg_comparison_{dataset_index}.png"
        if save_path:
            import os
            filename = os.path.join(save_path, filename)
        plt.savefig(filename, dpi=600, bbox_inches='tight')
    
    plt.show()
# check 11/20/25

# %% [markdown]
# ### Load data

# %% [markdown]
# #### Unpickled

# %%
subjid = 'hydrolagusColliei_8'
pattern = f"/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/*{subjid}*.mat"

data, freq_amp_table = read_data(subjid,pattern)
fs, latency, channel_keys, period_keys, metric_keys, submetric_keys = define_basic_vars()
# Out:
# ['/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211149_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211228_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211310_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211343_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211349_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat', '/mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat']
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 2073557622 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211149_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 137726443 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211228_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 1053456398 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211310_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 1160701828 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211343_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 338076318 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211349_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 11789018 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat
#   Exists: True
#   Is file: True
#   File size: 5132207201 bytes
#
# Checking file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat
#   Exists: True
#   Is file: True
#   File size: 7753168 bytes
#  sig_ref shape (4, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (12, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
#   all_batches array shape: (12, 10584, 50)
#  sig_ref shape (12, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
#   all_batches array shape: (12, 10584, 50)
#  sig_ref shape (12, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
#   all_batches array shape: (12, 10584, 50)
#  sig_ref shape (12, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
#   all_batches array shape: (12, 10584, 50)
#  sig_ref shape (16, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
#   all_batches array shape: (16, 10584, 50)
#  sig_ref shape (16, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
#   all_batches array shape: (16, 10584, 50)
#  sig_ref shape (16, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
#   all_batches array shape: (16, 10584, 50)
#  sig_ref shape (16, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
#   all_batches array shape: (16, 10584, 50)
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,5, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,6, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,7, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,11, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,12, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,13, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,14, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,15, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,16, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,17, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,18, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,19, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,20, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,21, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,22, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,23, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,24, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,25, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,26, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,27, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,28, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,29, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,0,30, does not have references
#  sig_ref shape (3, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (2, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
#   all_batches array shape: (2, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (4, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
#   all_batches array shape: (4, 10584, 50)
#  sig_ref shape (8, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
#   all_batches array shape: (8, 10584, 50)
#  sig_ref shape (8, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
#   all_batches array shape: (8, 10584, 50)
#  sig_ref shape (8, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
#   all_batches array shape: (8, 10584, 50)
#  sig_ref shape (8, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
#   all_batches array shape: (8, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (3, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
#   all_batches array shape: (3, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (20, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 17
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 18
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 19
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 20
#   all_batches array shape: (20, 10584, 50)
#  sig_ref shape (20, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 17
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 18
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 19
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 20
#   all_batches array shape: (20, 10584, 50)
#  sig_ref shape (20, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 17
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 18
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 19
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 20
#   all_batches array shape: (20, 10584, 50)
#  sig_ref shape (20, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 7
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 8
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 9
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 10
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 11
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 12
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 13
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 14
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 15
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 16
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 17
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 18
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 19
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 20
#   all_batches array shape: (20, 10584, 50)
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,11, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,12, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,13, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,14, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,15, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,16, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,17, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,18, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,19, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,20, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,21, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,22, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,23, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,24, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,25, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,26, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,27, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,28, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,29, does not have references
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,1,30, does not have references
#  sig_ref shape (6, 1)
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch1
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch2
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch3
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
#  sig_ref shape (6, 1)
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 50)
#   len(all_batches): 6
#   all_batches array shape: (6, 10584, 50)
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,1, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,2, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,3, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,4, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,5, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,6, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,7, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211143_1_run.mat,2,11, does not have data inside
# ...
#   len(all_batches): 1
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 2
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 3
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 4
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 5
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 6
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 7
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 8
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 9
# Channel: ch4
#   current_batch_all_periods shape: (10584, 100)
#   len(all_batches): 10
#   all_batches array shape: (10, 10584, 100)
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,5, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,6, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,7, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,11, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,12, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,13, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,14, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,15, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,16, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,17, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,18, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,19, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,20, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,21, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,22, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211524_1_run.mat,2,23, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,0, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,1, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,2, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,3, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,4, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,5, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,6, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,7, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,11, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,12, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,13, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,14, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,15, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,16, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,17, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,18, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,19, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,0,20, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,0, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,1, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,2, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,3, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,4, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,5, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,6, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,7, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,11, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,12, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,13, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,14, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,15, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,16, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,17, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,18, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,19, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,1,20, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,0, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,1, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,2, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,3, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,4, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,5, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,6, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,7, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,8, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,9, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,10, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,11, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,12, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,13, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,14, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,15, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,16, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,17, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,18, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,19, does not have data inside
# /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211537_1_run_NODATA.mat,2,20, does not have data inside

# %% [markdown]
# #### Pickled

# %%
# subjid = 'hydrolagusColliei_8'
# data, freq_amp_table, latency, channel_keys, period_keys, metric_keys, submetric_keys = load_data(subjid)

# %% [markdown]
# ### What stim combos do we have?

# %%
freq_amp_table_df = pd.DataFrame(freq_amp_table).sort_values(by= [0,1],ascending=True)
freq_amp_table_df
# Out:
#          0      1
# 30    55.0   90.0
# 4     55.0   95.0
# 29    55.0   95.0
# 3     55.0  100.0
# 28    55.0  100.0
# 2     55.0  105.0
# 27    55.0  105.0
# 1     55.0  110.0
# 26    55.0  110.0
# 0     55.0  115.0
# 25    55.0  115.0
# 37    70.0   85.0
# 36    70.0   90.0
# 35    70.0   95.0
# 34    70.0  100.0
# 33    70.0  105.0
# 32    70.0  110.0
# 31    70.0  115.0
# 42   100.0   95.0
# 18   100.0  100.0
# 41   100.0  100.0
# 17   100.0  105.0
# 40   100.0  105.0
# 16   100.0  110.0
# 39   100.0  110.0
# 15   100.0  115.0
# 38   100.0  115.0
# 12   220.0   90.0
# 11   220.0   95.0
# 10   220.0  100.0
# 9    220.0  105.0
# 8    220.0  110.0
# 7    220.0  115.0
# 6    220.0  120.0
# 5    220.0  125.0
# 21   330.0  150.0
# 24   330.0  150.0
# 22   360.0  150.0
# 23   385.0  150.0
# 19   440.0  150.0
# 14   880.0  140.0
# 13   880.0  150.0
# 20  1695.0  150.0

# %% [markdown]
# ### Data cleaning

# %%
cleaned_data = remove_artefacts(data)
# Out:
# Processing coord (np.float64(55.0), np.float64(115.0)), dataset 0
# (198, 10584)
# ch1: rms = (198,)
# (198, 10584)
# ch2: rms = (198,)
# (198, 10584)
# ch3: rms = (198,)
# (198, 10584)
# ch4: rms = (198,)
# Processing coord (np.float64(55.0), np.float64(115.0)), dataset 1
# (97, 10584)
# ch1: rms = (97,)
# (97, 10584)
# ch2: rms = (97,)
# (97, 10584)
# ch3: rms = (97,)
# (97, 10584)
# ch4: rms = (97,)
# Processing coord (np.float64(55.0), np.float64(110.0)), dataset 0
# (98, 10584)
# ch1: rms = (98,)
# (98, 10584)
# ch2: rms = (98,)
# (98, 10584)
# ch3: rms = (98,)
# (98, 10584)
# ch4: rms = (98,)
# Processing coord (np.float64(55.0), np.float64(110.0)), dataset 1
# (97, 10584)
# ch1: rms = (97,)
# (97, 10584)
# ch2: rms = (97,)
# (97, 10584)
# ch3: rms = (97,)
# (97, 10584)
# ch4: rms = (97,)
# Processing coord (np.float64(55.0), np.float64(105.0)), dataset 0
# (147, 10584)
# ch1: rms = (147,)
# (147, 10584)
# ch2: rms = (147,)
# (147, 10584)
# ch3: rms = (147,)
# (147, 10584)
# ch4: rms = (147,)
# Processing coord (np.float64(55.0), np.float64(105.0)), dataset 1
# (198, 10584)
# ch1: rms = (198,)
# (198, 10584)
# ch2: rms = (198,)
# (198, 10584)
# ch3: rms = (198,)
# (198, 10584)
# ch4: rms = (198,)
# Processing coord (np.float64(55.0), np.float64(100.0)), dataset 0
# (595, 10584)
# ch1: rms = (595,)
# (595, 10584)
# ch2: rms = (595,)
# (595, 10584)
# ch3: rms = (595,)
# (595, 10584)
# ch4: rms = (595,)
# Processing coord (np.float64(55.0), np.float64(100.0)), dataset 1
# (195, 10584)
# ch1: rms = (195,)
# (195, 10584)
# ch2: rms = (195,)
# (195, 10584)
# ch3: rms = (195,)
# (195, 10584)
# ch4: rms = (195,)
# Processing coord (np.float64(55.0), np.float64(95.0)), dataset 0
# (781, 10584)
# ch1: rms = (781,)
# (781, 10584)
# ch2: rms = (781,)
# (781, 10584)
# ch3: rms = (781,)
# (781, 10584)
# ch4: rms = (781,)
# Processing coord (np.float64(55.0), np.float64(95.0)), dataset 1
# (488, 10584)
# ch1: rms = (488,)
# (488, 10584)
# ch2: rms = (488,)
# (488, 10584)
# ch3: rms = (488,)
# (488, 10584)
# ch4: rms = (488,)
# Processing coord (np.float64(220.0), np.float64(125.0)), dataset 0
# (148, 10584)
# ch1: rms = (148,)
# (148, 10584)
# ch2: rms = (148,)
# (148, 10584)
# ch3: rms = (148,)
# (148, 10584)
# ch4: rms = (148,)
# Processing coord (np.float64(220.0), np.float64(120.0)), dataset 0
# (196, 10584)
# ch1: rms = (196,)
# (196, 10584)
# ch2: rms = (196,)
# (196, 10584)
# ch3: rms = (196,)
# (196, 10584)
# ch4: rms = (196,)
# Processing coord (np.float64(220.0), np.float64(115.0)), dataset 0
# (99, 10584)
# ch1: rms = (99,)
# (99, 10584)
# ch2: rms = (99,)
# (99, 10584)
# ch3: rms = (99,)
# (99, 10584)
# ch4: rms = (99,)
# Processing coord (np.float64(220.0), np.float64(110.0)), dataset 0
# (196, 10584)
# ch1: rms = (196,)
# (196, 10584)
# ch2: rms = (196,)
# (196, 10584)
# ch3: rms = (196,)
# (196, 10584)
# ch4: rms = (196,)
# Processing coord (np.float64(220.0), np.float64(105.0)), dataset 0
# (391, 10584)
# ch1: rms = (391,)
# (391, 10584)
# ch2: rms = (391,)
# (391, 10584)
# ch3: rms = (391,)
# (391, 10584)
# ch4: rms = (391,)
# Processing coord (np.float64(220.0), np.float64(100.0)), dataset 0
# (146, 10584)
# ch1: rms = (146,)
# (146, 10584)
# ch2: rms = (146,)
# (146, 10584)
# ch3: rms = (146,)
# (146, 10584)
# ch4: rms = (146,)
# Processing coord (np.float64(220.0), np.float64(95.0)), dataset 0
# (297, 10584)
# ch1: rms = (297,)
# (297, 10584)
# ch2: rms = (297,)
# (297, 10584)
# ch3: rms = (297,)
# (297, 10584)
# ch4: rms = (297,)
# Processing coord (np.float64(220.0), np.float64(90.0)), dataset 0
# (998, 10584)
# ch1: rms = (998,)
# (998, 10584)
# ch2: rms = (998,)
# (998, 10584)
# ch3: rms = (998,)
# (998, 10584)
# ch4: rms = (998,)
# Processing coord (np.float64(880.0), np.float64(150.0)), dataset 0
# (297, 10584)
# ch1: rms = (297,)
# (297, 10584)
# ch2: rms = (297,)
# (297, 10584)
# ch3: rms = (297,)
# (297, 10584)
# ch4: rms = (297,)
# Processing coord (np.float64(880.0), np.float64(140.0)), dataset 0
# (299, 10584)
# ch1: rms = (299,)
# (299, 10584)
# ch2: rms = (299,)
# (299, 10584)
# ch3: rms = (299,)
# (299, 10584)
# ch4: rms = (299,)
# Processing coord (np.float64(100.0), np.float64(115.0)), dataset 0
# (146, 10584)
# ch1: rms = (146,)
# (146, 10584)
# ch2: rms = (146,)
# (146, 10584)
# ch3: rms = (146,)
# (146, 10584)
# ch4: rms = (146,)
# Processing coord (np.float64(100.0), np.float64(115.0)), dataset 1
# (97, 10584)
# ch1: rms = (97,)
# (97, 10584)
# ch2: rms = (97,)
# (97, 10584)
# ch3: rms = (97,)
# (97, 10584)
# ch4: rms = (97,)
# Processing coord (np.float64(100.0), np.float64(110.0)), dataset 0
# (99, 10584)
# ch1: rms = (99,)
# (99, 10584)
# ch2: rms = (99,)
# (99, 10584)
# ch3: rms = (99,)
# (99, 10584)
# ch4: rms = (99,)
# Processing coord (np.float64(100.0), np.float64(110.0)), dataset 1
# (491, 10584)
# ch1: rms = (491,)
# (491, 10584)
# ch2: rms = (491,)
# (491, 10584)
# ch3: rms = (491,)
# (491, 10584)
# ch4: rms = (491,)
# Processing coord (np.float64(100.0), np.float64(105.0)), dataset 0
# (98, 10584)
# ch1: rms = (98,)
# (98, 10584)
# ch2: rms = (98,)
# (98, 10584)
# ch3: rms = (98,)
# (98, 10584)
# ch4: rms = (98,)
# Processing coord (np.float64(100.0), np.float64(105.0)), dataset 1
# (393, 10584)
# ch1: rms = (393,)
# (393, 10584)
# ch2: rms = (393,)
# (393, 10584)
# ch3: rms = (393,)
# (393, 10584)
# ch4: rms = (393,)
# Processing coord (np.float64(100.0), np.float64(100.0)), dataset 0
# (989, 10584)
# ch1: rms = (989,)
# (989, 10584)
# ch2: rms = (989,)
# (989, 10584)
# ch3: rms = (989,)
# (989, 10584)
# ch4: rms = (989,)
# Processing coord (np.float64(100.0), np.float64(100.0)), dataset 1
# (491, 10584)
# ch1: rms = (491,)
# (491, 10584)
# ch2: rms = (491,)
# (491, 10584)
# ch3: rms = (491,)
# (491, 10584)
# ch4: rms = (491,)
# Processing coord (np.float64(440.0), np.float64(150.0)), dataset 0
# (493, 10584)
# ch1: rms = (493,)
# (493, 10584)
# ch2: rms = (493,)
# (493, 10584)
# ch3: rms = (493,)
# (493, 10584)
# ch4: rms = (493,)
# Processing coord (np.float64(1695.0), np.float64(150.0)), dataset 0
# (492, 10584)
# ch1: rms = (492,)
# (492, 10584)
# ch2: rms = (492,)
# (492, 10584)
# ch3: rms = (492,)
# (492, 10584)
# ch4: rms = (492,)
# Processing coord (np.float64(330.0), np.float64(150.0)), dataset 0
# (983, 10584)
# ch1: rms = (983,)
# (983, 10584)
# ch2: rms = (983,)
# (983, 10584)
# ch3: rms = (983,)
# (983, 10584)
# ch4: rms = (983,)
# Processing coord (np.float64(330.0), np.float64(150.0)), dataset 1
# (998, 10584)
# ch1: rms = (998,)
# (998, 10584)
# ch2: rms = (998,)
# (998, 10584)
# ch3: rms = (998,)
# (998, 10584)
# ch4: rms = (998,)
# Processing coord (np.float64(360.0), np.float64(150.0)), dataset 0
# (998, 10584)
# ch1: rms = (998,)
# (998, 10584)
# ch2: rms = (998,)
# (998, 10584)
# ch3: rms = (998,)
# (998, 10584)
# ch4: rms = (998,)
# Processing coord (np.float64(385.0), np.float64(150.0)), dataset 0
# (538, 10584)
# ch1: rms = (538,)
# (538, 10584)
# ch2: rms = (538,)
# (538, 10584)
# ch3: rms = (538,)
# (538, 10584)
# ch4: rms = (538,)
# Processing coord (np.float64(55.0), np.float64(90.0)), dataset 0
# (974, 10584)
# ch1: rms = (974,)
# (974, 10584)
# ch2: rms = (974,)
# (974, 10584)
# ch3: rms = (974,)
# (974, 10584)
# ch4: rms = (974,)
# Processing coord (np.float64(70.0), np.float64(115.0)), dataset 0
# (199, 10584)
# ch1: rms = (199,)
# (199, 10584)
# ch2: rms = (199,)
# (199, 10584)
# ch3: rms = (199,)
# (199, 10584)
# ch4: rms = (199,)
# Processing coord (np.float64(70.0), np.float64(110.0)), dataset 0
# (97, 10584)
# ch1: rms = (97,)
# (97, 10584)
# ch2: rms = (97,)
# (97, 10584)
# ch3: rms = (97,)
# (97, 10584)
# ch4: rms = (97,)
# Processing coord (np.float64(70.0), np.float64(105.0)), dataset 0
# (96, 10584)
# ch1: rms = (96,)
# (96, 10584)
# ch2: rms = (96,)
# (96, 10584)
# ch3: rms = (96,)
# (96, 10584)
# ch4: rms = (96,)
# Processing coord (np.float64(70.0), np.float64(100.0)), dataset 0
# (98, 10584)
# ch1: rms = (98,)
# (98, 10584)
# ch2: rms = (98,)
# (98, 10584)
# ch3: rms = (98,)
# (98, 10584)
# ch4: rms = (98,)
# Processing coord (np.float64(70.0), np.float64(95.0)), dataset 0
# (195, 10584)
# ch1: rms = (195,)
# (195, 10584)
# ch2: rms = (195,)
# (195, 10584)
# ch3: rms = (195,)
# (195, 10584)
# ch4: rms = (195,)
# Processing coord (np.float64(70.0), np.float64(90.0)), dataset 0
# (689, 10584)
# ch1: rms = (689,)
# (689, 10584)
# ch2: rms = (689,)
# (689, 10584)
# ch3: rms = (689,)
# (689, 10584)
# ch4: rms = (689,)
# Processing coord (np.float64(70.0), np.float64(85.0)), dataset 0
# (994, 10584)
# ch1: rms = (994,)
# (994, 10584)
# ch2: rms = (994,)
# (994, 10584)
# ch3: rms = (994,)
# (994, 10584)
# ch4: rms = (994,)
# Processing coord (np.float64(100.0), np.float64(95.0)), dataset 0
# (997, 10584)
# ch1: rms = (997,)
# (997, 10584)
# ch2: rms = (997,)
# (997, 10584)
# ch3: rms = (997,)
# (997, 10584)
# ch4: rms = (997,)

# %% [markdown]
# ### Select stimulus

# %%
# Select stimulus
myfreq = 100
myamp = 115
dataset_index = 0
current_cond = select_stimulus(cleaned_data, myfreq, myamp, dataset_index)
plot_waveforms(current_cond, channel_keys, title='Check waveforms', num_samples=5, figsize=(8, 4), alpha=0.25)
print(current_cond['ch1'].shape)
# Out:
# Found 2 dataset(s) for freq=100, amp=115
# Selecting dataset 0 from file: /mnt/c/Users/Aoi Hunsaker/Documents/accel_fall_25/data/ratfish/june_2025/Ratfish_6thGo/hydrolagusColliei_8_AdaptiveAEP_Ratfish_2506211228_1_run.mat
# (143, 10584)

# %% [markdown]
# ### Bandpass filter

# %%
low, high = 70, 1400 # Getting rid of junk thats all it is! Don't center on the double frequency response, filtering = bias, base on auditory range, don't introduce that I know what to expect for this given stimulus frequency
filt_data = {}
for channel in channel_keys:
    tmp = []
    cur_data = current_cond[channel]
    tmp.append(bandpass(cur_data, low, high, fs))
    filt_data[channel] = np.hstack(tmp)

# %%
plot_waveforms(filt_data, channel_keys, 
               title='Check waveforms', num_samples=5, figsize=(8, 4), alpha=0.25)
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  array([<Axes: ylabel='ch1'>, <Axes: ylabel='ch2'>, <Axes: ylabel='ch3'>,
#         <Axes: ylabel='ch4'>], dtype=object))

# %% [markdown]
# ### ICA

# %%
reshaped_data = reshape_the_data(filt_data, channel_keys, period_keys)
#reshaped_data = reshape_the_data(current_cond, channel_keys, period_keys)
ica_results = perform_ICA(reshaped_data, channel_keys)
input_data = ica_results['S']
ica_fft_magnitudes, ica_fft_freq_vec = compute_fft(
    input_data, channel_keys=[], period_keys=[], smallest_dim = 1, fs=fs)
# Out:
# Elapsed time: 0.96 seconds
# ICA Convergence: 6

# %%
# plot_waveforms(input_data, channel_keys=[], 
#                title='Check ICA Waveforms', num_samples=[], figsize=(8, 4), alpha=1.0)
# plot_fft(ica_fft_magnitudes, ica_fft_freq_vec, myfreq, myamp, subjid, dataset_index, channel_keys=[], period_keys=[],
#          title='Check ICA FFTs', num_samples=5, figsize=(8, 4), alpha=1.0,xlim=[myfreq*2-100,myfreq*2+100], ylim=[0,0.002])

# %%
ica_doub_freq = select_doub_freq_bin(ica_fft_magnitudes, ica_fft_freq_vec, [], myfreq, window_size=100)
weights = create_ICA_weights(ica_doub_freq)
recon_restruct_data = weight_and_reconstruct_ica(ica_results, current_cond, channel_keys, [0,1,2,3], component_weights=None)
weights
# Out:
# (11026,)
# [197. 198. 199. 200. 201. 202. 203.]
# [150. 151. 152. 153. 154. 155. 156. 157. 158. 159. 160. 161. 162. 163.
#  164. 165. 166. 167. 168. 169. 170. 171. 172. 173. 174. 175. 176. 177.
#  178. 179. 180. 181. 182. 183. 184. 185. 186. 187. 188. 189. 190. 191.
#  192. 193. 194. 195. 196. 197. 198. 199. 200. 201. 202. 203. 204. 205.
#  206. 207. 208. 209. 210. 211. 212. 213. 214. 215. 216. 217. 218. 219.
#  220. 221. 222. 223. 224. 225. 226. 227. 228. 229. 230. 231. 232. 233.
#  234. 235. 236. 237. 238. 239. 240. 241. 242. 243. 244. 245. 246. 247.
#  248. 249. 250.]
# [150. 151. 152. 153. 154. 155. 156. 157. 158. 159. 160. 161. 162. 163.
#  164. 165. 166. 167. 168. 169. 170. 171. 172. 173. 174. 175. 176. 184.
#  185. 186. 187. 188. 189. 190. 191. 192. 193. 194. 195. 196. 204. 205.
#  206. 207. 208. 209. 210. 211. 212. 213. 214. 215. 216. 217. 218. 219.
#  220. 221. 222. 223. 224. 225. 226. 227. 228. 229. 230. 231. 232. 233.
#  234. 235. 236. 244. 245. 246. 247. 248. 249. 250.]
# 0.000271085812717496
# 0.000313672620214183
# dB subtraction performed!
# 0.0004434023674238907
# 0.0003553208704053441
# dB subtraction performed!
# 0.0003200950606228749
# 0.0003354673014834927
# dB subtraction performed!
# 0.000315373339719342
# 0.0002781792660027798
# dB subtraction performed!
# array([0.24999658, 0.2500041 , 0.24999815, 0.25000117])

# %% [markdown]
# ### Save weights to csv

# %%
weights_df = pd.DataFrame({
    'subjid': [subjid] * len(weights),
    'freq': [myfreq] * len(weights),
    'amp': [myamp] * len(weights),
    'channel': channel_keys,
    'weight': weights
})

# # Save to CSV
# weights_df.to_csv(f'weights_csv/{subjid}/{subjid}_{myfreq}Hz_{myamp}dB_weights_{dataset_index}.csv', index=False)

# %% [markdown]
# ### Compare denoised signal to original signal

# %%
# compare_denoising_mean, compare_denoising_std, fft_magnitudes_mean, fft_magnitudes_std, fft_freq_vecs = compare_denoised_waveform(
#                           filt_data, recon_restruct_data, 
#                           channel_keys, myfreq, 
#                           myamp, subjid, fs, dataset_index,
#                           fft_ylim=[0, 0.04])

# %% [markdown]
# ### Add weights to time domain trials

# %%
# weights = [0.25,0.25,0.25,0.25]
# weighted_data = add_weights(current_cond, channel_keys, weights)

# %% [markdown]
# ### Separate denoised data

# %%
separated_data = separate_periods(recon_restruct_data, current_cond, period_keys, channel_keys, latency)
weighted_ffts, weighted_freq_vec = compute_fft(separated_data, channel_keys, period_keys, smallest_dim=[], fs=fs)
# plot_fft(weighted_ffts, weighted_freq_vec, myfreq, myamp, subjid, dataset_index, channel_keys,
#             period_keys=period_keys, 
#             title='Check ffts separated', 
#             num_samples=5, 
#             figsize=(8, 4), 
#             alpha=0.25,
#             xlim=[myfreq*2-100,myfreq*2+100],
#             ylim=[0,0.25]
# )

# %% [markdown]
# ### Collapse channels

# %%
collapsed_dict = collapse_channels(weighted_ffts, period_keys, channel_keys)
collapsed_dict
# Out:
# {'prestim': array([[3.54823220e-03, 3.18991063e-03, 2.29580791e-03, ...,
#          2.46933341e-04, 1.75857811e-04, 1.28143420e-04],
#         [5.62896088e-04, 2.60282085e-03, 4.46916048e-03, ...,
#          1.89962308e-04, 2.68889263e-04, 2.99637412e-04],
#         [6.37411733e-03, 5.69176930e-03, 3.95394472e-03, ...,
#          2.67618459e-04, 2.47579094e-04, 2.37299645e-04],
#         ...,
#         [9.78858875e-03, 9.37235783e-03, 8.44224841e-03, ...,
#          5.88520177e-05, 8.28956486e-05, 9.22860059e-05],
#         [3.12121536e-03, 3.37068244e-03, 3.86779576e-03, ...,
#          1.27098201e-04, 1.71255672e-04, 1.88911884e-04],
#         [7.37471216e-03, 6.90436114e-03, 5.79461547e-03, ...,
#          1.66452911e-04, 1.16694489e-04, 8.25629580e-05]],
#        shape=(572, 11026)),
#  'stimresp': array([[2.07988230e-03, 4.14979041e-03, 6.60847986e-03, ...,
#          2.23527549e-04, 1.86846550e-04, 1.66269374e-04],
#         [4.49788945e-03, 3.91901291e-03, 2.36654680e-03, ...,
#          9.78739028e-05, 8.20495051e-05, 7.31966255e-05],
#         [6.66649717e-03, 5.99723429e-03, 4.27193571e-03, ...,
#          3.73652466e-05, 2.14282352e-05, 2.63731651e-06],
#         ...,
#         [2.14586757e-03, 1.88692979e-03, 1.17454567e-03, ...,
#          9.89846612e-05, 5.74991571e-05, 1.31337707e-05],
#         [4.27031193e-03, 4.01786757e-03, 3.47047983e-03, ...,
#          2.05645944e-04, 1.59210946e-04, 1.31033338e-04],
#         [7.31388533e-03, 6.86686097e-03, 5.82139030e-03, ...,
#          1.30560372e-04, 1.45022099e-04, 1.51509606e-04]],
#        shape=(572, 11026))}

# %% [markdown]
# ### Calculate dB of fft vals

# %%
collapsed_dict_dB = {}
collapsed_dict_dB['prestim'] = 20 * np.log10(collapsed_dict['prestim'])
collapsed_dict_dB['stimresp'] = 20 * np.log10(collapsed_dict['stimresp'])

# %% [markdown]
# ### Calculate per trial subtraction of stim OFF and ON trials

# %%
diffs = collapsed_dict_dB['stimresp'] - collapsed_dict_dB['prestim']
cur_freq_vec = weighted_freq_vec['prestim']['ch1'][0]
target_freq = myfreq*2
plt.plot(cur_freq_vec,diffs[0])
plt.xlim([target_freq*0.5,target_freq*1.5])
plt.axvline(target_freq, linestyle='--', alpha=0.5, color = 'red')

# %%
diff_doub_bin = select_doub_freq_bin(diffs,weighted_freq_vec['prestim']['ch1'],[],myfreq)

diff_doub_bin
# Out:
# (11026,)
# [197. 198. 199. 200. 201. 202. 203.]
# [150. 151. 152. 153. 154. 155. 156. 157. 158. 159. 160. 161. 162. 163.
#  164. 165. 166. 167. 168. 169. 170. 171. 172. 173. 174. 175. 176. 177.
#  178. 179. 180. 181. 182. 183. 184. 185. 186. 187. 188. 189. 190. 191.
#  192. 193. 194. 195. 196. 197. 198. 199. 200. 201. 202. 203. 204. 205.
#  206. 207. 208. 209. 210. 211. 212. 213. 214. 215. 216. 217. 218. 219.
#  220. 221. 222. 223. 224. 225. 226. 227. 228. 229. 230. 231. 232. 233.
#  234. 235. 236. 237. 238. 239. 240. 241. 242. 243. 244. 245. 246. 247.
#  248. 249. 250.]
# [150. 151. 152. 153. 154. 155. 156. 157. 158. 159. 160. 161. 162. 163.
#  164. 165. 166. 167. 168. 169. 170. 171. 172. 173. 174. 175. 176. 184.
#  185. 186. 187. 188. 189. 190. 191. 192. 193. 194. 
#         41., 60., 47., 59., 43., 39., 37., 26., 23., 11., 17.,  9.,  3.,
#          3.,  1.,  0.,  2.]),
#  array([-19.15823151, -17.86261928, -16.56700706, -15.27139483,
#         -13.97578261, -12.68017038, -11.38455816, -10.08894594,
#          -8.79333371,  -7.49772149,  -6.20210926,  -4.90649704,
#          -3.61088481,  -2.31527259,  -1.01966036,   0.27595186,
#           1.57156409,   2.86717631,   4.16278854,   5.45840076,
#           6.75401299,   8.04962521,   9.34523744,  10.64084966,
#          11.93646188,  13.23207411,  14.52768633,  15.82329856,
#          17.11891078,  18.41452301,  19.71013523]),
#  <BarContainer object of 30 artists>)

# %%
lower = float(np.percentile(diff_doub_bin['doub_freq_mag'], 2.5))
upper = float(np.percentile(diff_doub_bin['doub_freq_mag'], 97.5))
print(lower)
print(upper)
# Out:
# -10.321176977765884
# 12.244916711472712

# %% [markdown]
# ### Calculate bootstrapped estimates of mean difference

# %%
n_iterations = 1000
random_state=42
cur_data = diff_doub_bin['doub_freq_mag']
rng = np.random.default_rng(random_state) # create a standalone random number generator object
max_samples = cur_data.shape[0]

boot_means = []
boot_std = []

for _ in range(n_iterations):
    sample_indices = rng.choice(max_samples, size=max_samples, replace=True)
    resampled_data = cur_data[sample_indices]

    boot_means.append(float(np.mean(resampled_data, axis=0)))
    boot_std.append(float(np.std(resampled_data, axis=0)))
    
boot_means
# Out:
# [1.1003559239327587,
#  1.0431135746832667,
#  0.9751362707289039,
#  1.0442534078251817,
#  1.429116538856023,
#  1.3414824626422464,
#  1.7996002268558575,
#  0.927432357094413,
#  0.7376243999795515,
#  1.2657120411542182,
#  1.5204129487286493,
#  1.4123062221583642,
#  0.9446899022665517,
#  0.9897323399213274,
#  1.1280537167562168,
#  0.9682564318168447,
#  1.0674542965134037,
#  0.9185967236774774,
#  0.7846604822058253,
#  0.8644465209473864,
#  1.0448563188278166,
#  1.162240410422733,
#  1.3549105142093774,
#  0.2983738179260153,
#  1.6228335343608513,
#  0.7118148405282322,
#  0.7569893775845413,
#  1.2773392358869609,
#  1.2475219759672345,
#  1.8282515634551402,
#  1.3768907786547415,
#  1.0979723325540127,
#  1.1131696020427249,
#  0.9100313685376716,
#  1.2609794499826903,
#  1.493873001205125,
#  1.526080335869254,
#  1.147321083910218,
#  1.0358213298775416,
#  1.079034727583867,
#  1.4970663467880523,
#  1.382805552662841,
#  0.8371133362747128,
#  1.0439853824028638,
#  0.9366875650488227,
#  1.1310405876392544,
#  1.141633687054997,
#  1.2034258235368929,
#  1.2323597857231423,
#  1.113178074006306,
#  1.3625310513355717,
#  1.4509467451017026,
#  1.0642969692888968,
#  1.0785881446195513,
#  1.124126509597667,
#  1.148579151518068,
#  1.262048100626235,
#  0.9402541145380429,
#  0.9221906511067761,
#  1.1855017470487614,
#  0.7870743922565135,
#  0.6763662649443217,
#  1.468362569166,
#  1.1492161121754476,
#  0.8751580780930311,
#  1.0947174657363945,
#  1.0736959287328445,
#  1.1277953553560927,
#  1.3258206020292629,
#  1.1206759343000439,
#  1.0242159709404601,
#  1.0642849643667953,
#  1.2266247693519376,
#  1.0981926432950542,
#  1.1120164254373215,
#  1.3339063725311433,
#  1.2105741732949145,
#  0.7901990065182819,
#  0.9211041500205596,
#  1.7024425636904914,
#  0.9966066996684197,
#  0.746589979965288,
#  1.156674784610637]

# %%
plt.hist(boot_means,bins=30)
plt.title(f"{subjid}: {myfreq} Hz, {myamp} dB")
plt.xlim([-1.0,5.5])
plt.ylim([0,100])
# Out:
# (0.0, 100.0)

# %%
lower = float(np.percentile(boot_means, 2.5))
upper = float(np.percentile(boot_means, 97.5))

print("95% CI:", (lower, upper))

# 3. Decision rule: if CI excludes 0 → significant
if lower > 0 or upper < 0:
    print("Groups differ significantly (CI excludes 0).")
else:
    print("No significant difference (CI includes 0).")
# Out:
# 95% CI: (0.6980779637127363, 1.6468878847205355)
# Groups differ significantly (CI excludes 0).

# %% [markdown]
# ### Calculate bootstrapped SNR by period

# %% [markdown]
# ### Save results

# %%
# save_data = {
#     'subjid': subjid, 'fs': fs, 'latency': latency, 'channel_keys': channel_keys,
#     'period_keys': period_keys, 'metric_keys': metric_keys, 'submetric_keys': submetric_keys,
#     'freq_amp_table_df': freq_amp_table_df, 'myfreq': myfreq, 'myamp': myamp,
#     'low': low, 'high': high, 'filt_data': filt_data, 'input_data': input_data,
#     'ica_fft_magnitudes': ica_fft_magnitudes, 'ica_fft_freq_vec': ica_fft_freq_vec,
#     'ica_doub_freq': ica_doub_freq, 'weights': weights, 'recon_restruct_data': recon_restruct_data,
#     'compare_denoising_mean': compare_denoising_mean, 'compare_denoising_std': compare_denoising_std,
#     'fft_magnitudes_mean': fft_magnitudes_mean, 'fft_magnitudes_std': fft_magnitudes_std,
#     'fft_freq_vecs': fft_freq_vecs, 'weighted_ffts': weighted_ffts,
#     'weighted_freq_vec': weighted_freq_vec, 'mean_fft_prestim': mean_fft_prestim,
#     'std_fft_prestim': std_fft_prestim, 'mean_fft_stimresp': mean_fft_stimresp,
#     'std_fft_stimresp': std_fft_stimresp, 'freq_vec': freq_vec,
#     'doub_freq_dict': doub_freq_dict, 'diff_CI_results': diff_CI_results
# }
# with open(f'{subjid}_{myfreq}Hz_{myamp}dB.pkl', 'wb') as f:
#     pickle.dump(save_data, f)

# %% [markdown]
# ### Play sound to let me know I am done!

# %%
# # To load them back:
# data = load_variables('my_analysis.pkl')
# subjid = data['subjid']
# fs = data['fs']
# # ... etc for all variables

# %% [markdown]
# ### Notes

# %%
# Denoise/Make best use of all channels
# by applying weights to each channel based on how stable their mean estimate of
# the double frequency response

# Artefact rejection

# Step 1: Add weights to per trial time domain signals by channel 
# Step 2: Conduct ffts on per trial basis on the weighted trials as one mega-channel
# Step 3: In FFT land, calculate the difference between stim and prestim on trial by trial basis
# Step 4: Take the mean on the differences
# Step 5: Calculate the standard deviation as well (optimize around reducing S as much as possible)
# Step 6: Calculate ICA

# After determining weights and performing ICA based denoising...
# Step 6: Bootstrap: Take the data generated from step 2, conduct bootstrap averaging per period, create a distribution of estimates of SNR for each period
# Step 7: 95% CI of the differences between prestim and stimresp
